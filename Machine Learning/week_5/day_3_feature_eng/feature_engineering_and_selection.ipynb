# %% [markdown]
# # AISOC Workshop: Feature Engineering and Selection
#
# NOTE: This notebook is currently in progress

# %% [markdown]
# ## 1. Techniques for Feature Engineering
#
# - Common operations for data preprocessing - drop columns, missing values, date conversion , etc
#
# - Feature transformation - scaling, log transform, Binning & Discretization
#
# - Feature extraction
#     - Time-based features: month, quarter, weekday, seasonality
#     - Customer/delivery-related features: shipping region, delivery status.
#     - Ratio features (Amount per Qty, etc.).
#     - Promotional features (binary flag for promotion presence).
#
# - Encoding techniques
#     - One-hot encoding (Category, Fulfilment, etc.), label encoding, target encoding,
#     - Frequency encoding for high-cardinality variables (SKU, Style, ASIN, ship-city)
#
# - Interaction & Polynomial Features
#     - Cross features (Category × Size)
#     - Multiplicative features (Qty × Avg Price)
#     - Polynomial features

# %% [markdown]
# ### Common operations for data preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv("Amazon Sale Report.csv")
# Out:
# C:\Users\pibzion\AppData\Local\Temp\ipykernel_59216\1208789707.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\pibzion\Downloads\Amazon Sale Report.csv")

# %%
df.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# 0            IN                                                NaN  False
# 1            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2            IN       IN Core Free Shipping 2015/04/08 23-48-5-108   True
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
# 1     Easy Ship         NaN
# 2           NaN         NaN
#
# [3 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %% [markdown]
# ***Drop unwanted columns***

# %%
cols_to_drop = ["index", "Unnamed: 22"]
df_clean = df.drop(columns=cols_to_drop)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  object
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      122103 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
#  15  ship-city           128942 non-null  object
#  16  ship-state          128942 non-null  object
#  17  ship-postal-code    128942 non-null  float64
#  18  ship-country        128942 non-null  object
#  19  promotion-ids       79822 non-null   object
#  20  B2B                 128975 non-null  bool
#  21  fulfilled-by        39277 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(18)
# memory usage: 20.8+ MB

# %% [markdown]
# ### Feature transformation techniques

# %% [markdown]
# ***Scaling***

# %% [markdown]
# Min-max: Uses the minimun and maximum values of a feature to rescale values to within a range.
#
# $$x' = \frac{x_i-min(x)}{max(x)-min(x)}$$
#
# Standard scaling: Scales the data such that it has a mean of 0 and a standard deviation of 1.
#
# $$x' = \frac{x_i-\bar{x}}{\sigma}$$
#
# Robust scaling: Improves on standard scaling to avoid negative impact of outliers, by using the median (Q2) and the interquartile range (Q3-Q1).
#
# <br>
#
# **PS: Interquartile range**
#
# $$x' = \frac{x_i-Q2}{IQR}$$
#
# - It is a measure of the spread of the middle 50% of a dataset.
# - It represents the difference between the 1st quartile (Q1) and 3rd quartile (Q3) where median is the 2nd quartile (Q2)
# - Q1 is the median of the lower half of the data, while Q3 is the median of the upper half

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
def check_feature_range(col):
    return (min(col), max(col))

num_cols = ["Qty", "Amount"]

for col in num_cols:
    feat = df[col]
    print(check_feature_range(feat))
# Out:
# (0, 15)
# (0.0, 5584.0)

# %%
df_scaled = df_clean.copy()

# %%
minmax_scaler = MinMaxScaler()
std_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %%
minmax_cols = [col+"_minmax" for col in num_cols]

df_scaled[minmax_cols] = minmax_scaler.fit_transform(df_clean[num_cols])
df_scaled.head(3)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ...  Amount    ship-city   ship-state ship-postal-code  ship-country  \
# 0  ...  647.62       MUMBAI  MAHARASHTRA         400081.0            IN
# 1  ...  406.00    BENGALURU    KARNATAKA         560085.0            IN
# 2  ...  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
#
#   Qty_minmax Amount_minmax
# 0   0.000000      0.115978
# 1   0.066667      0.072708
# 2   0.066667      0.058918
#
# [3 rows x 24 columns]

# %%
std_cols = [col+"_std" for col in num_cols]
df_scaled[std_cols] = std_scaler.fit_transform(df_clean[num_cols])
df_scaled.head(3)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ...   ship-state ship-postal-code  ship-country  \
# 0  ...  MAHARASHTRA         400081.0            IN
# 1  ...    KARNATAKA         560085.0            IN
# 2  ...  MAHARASHTRA         410210.0            IN
#
#                                        promotion-ids    B2B fulfilled-by  \
# 0                                                NaN  False    Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True          NaN
#
#   Qty_minmax  Amount_minmax   Qty_std Amount_std
# 0   0.000000       0.115978 -2.886307  -0.003348
# 1   0.066667       0.072708  0.304989  -0.862562
# 2   0.066667       0.058918  0.304989  -1.136378
#
# [3 rows x 26 columns]

# %%
robust_cols = [col+"_robust" for col in num_cols]
df_scaled[robust_cols] = robust_scaler.fit_transform(df_clean[num_cols])
df_scaled.head(3)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ... ship-country                                      promotion-ids    B2B  \
# 0  ...           IN                                                NaN  False
# 1  ...           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2  ...           IN       IN Core Free Shipping 2015/04/08 23-48-5-108   True
#
#   fulfilled-by  Qty_minmax Amount_minmax   Qty_std  Amount_std Qty_robust  \
# 0    Easy Ship    0.000000      0.115978 -2.886307   -0.003348       -1.0
# 1    Easy Ship    0.066667      0.072708  0.304989   -0.862562        0.0
# 2          NaN    0.066667      0.058918  0.304989   -1.136378        0.0
#
#   Amount_robust
# 0      0.125723
# 1     -0.587021
# 2     -0.814159
#
# [3 rows x 28 columns]

# %%
for col in minmax_cols:
    feat = df_scaled[col]
    print(check_feature_range(feat))
# Out:
# (0.0, 1.0)
# (0.0, 1.0)

# %%
for col in std_cols:
    feat = df_scaled[col]
    print(check_feature_range(feat))
# Out:
# (-2.8863068398180336, 44.98312513116297)
# (-2.306320008230719, 17.550689119906774)

# %%
for col in robust_cols:
    feat = df_scaled[col]
    print(check_feature_range(feat))
# Out:
# (-1.0, 14.0)
# (-1.7846607669616519, 14.687315634218288)

# %% [markdown]
# ### Feature extraction techniques

# %% [markdown]
# **Time-based features**
#
# Extract `day`, `month`, `year`, `day_of_week`, `is_weekend` (bool) - these are useful for seasonality, trends, behavior analysis

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df_temporal = df_clean.copy()

df_temporal["Date"] = pd.to_datetime(df_temporal["Date"], format="%m-%d-%y")
df_temporal["Date"]
# Out:
# 0        2022-04-30
# 1        2022-04-30
# 2        2022-04-30
# 3        2022-04-30
# 4        2022-04-30
#             ...
# 128970   2022-05-31
# 128971   2022-05-31
# 128972   2022-05-31
# 128973   2022-05-31
# 128974   2022-05-31
# Name: Date, Length: 128975, dtype: datetime64[ns]

# %%
df_temporal["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_temporal["order_day"] = df_temporal["Date"].dt.day
df_temporal["order_month"] = df_temporal["Date"].dt.month
df_temporal["order_year"] = df_temporal["Date"].dt.year
df_temporal["order_dayofweek"] = df_temporal["Date"].dt.dayofweek
df_temporal["is_weekend"] = df_temporal["order_dayofweek"].isin([5,6]).astype(int)

# %%
df_temporal.head(3)
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ... fulfilled-by Qty_minmax  Amount_minmax   Qty_std  Amount_std order_day  \
# 0  ...    Easy Ship   0.000000       0.115978 -2.886307   -0.003348        30
# 1  ...    Easy Ship   0.066667       0.072708  0.304989   -0.862562        30
# 2  ...          NaN   0.066667       0.058918  0.304989   -1.136378        30
#
#   order_month  order_year order_dayofweek is_weekend
# 0           4        2022               5          1
# 1           4        2022               5          1
# 2           4        2022               5          1
#
# [3 rows x 31 columns]

# %%
df_temporal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 31 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  object
#  1   Date                128975 non-null  datetime64[ns]
#  2   Status              128975 non-null  object
#  3   Fulfilment          128975 non-null  object
#  4   Sales Channel       128975 non-null  object
#  5   ship-service-level  128975 non-null  object
#  6   Style               128975 non-null  object
#  7   SKU                 128975 non-null  object
#  8   Category            128975 non-null  object
#  9   Size                128975 non-null  object
#  10  ASIN                128975 non-null  object
#  11  Courier Status      122103 non-null  object
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  object
#  14  Amount              121180 non-null  float64
#  15  ship-city           128942 non-null  object
#  16  ship-state          128942 non-null  object
#  17  ship-postal-code    128942 non-null  float64
#  18  ship-country        128942 non-null  object
#  19  promotion-ids       79822 non-null   object
#  20  B2B                 128975 non-null  bool
#  21  fulfilled-by        39277 non-null   object
#  22  Qty_minmax          128975 non-null  float64
#  23  Amount_minmax       121180 non-null  float64
#  24  Qty_std             128975 non-null  float64
#  25  Amount_std          121180 non-null  float64
#  26  order_day           128975 non-null  int32
#  27  order_month         128975 non-null  int32
#  28  order_year          128975 non-null  int32
#  29  order_dayofweek     128975 non-null  int32
#  30  is_weekend          128975 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(6), int32(4), int64(2), object(17)
# memory usage: 27.7+ MB
